# %% [markdown]
# #### Examine raw data pulled from Read_Write_Sensor python script

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_excel('WalkingData_3.xlsx')

df.head()
# Out:
#    Unnamed: 0  Sensor 1  Sensor 2  Sensor 3  Sensor 4  d_Sensor 1  d_Sensor 2  \
# 0           0  0.409730  0.444324  0.405405  0.405405    0.000000    0.000000
# 1           1  0.407568  0.442162  0.403243  0.405405   -0.117893   -0.117893
# 2           2  0.405399  0.439994  0.399629  0.405405   -0.159958   -0.159958
# 3           3  0.403223  0.438907  0.397812  0.405405   -0.181063   -0.146188
# 4           4  0.402790  0.439127  0.396721  0.405405   -0.147555   -0.105201
#
#    d_Sensor 3  d_Sensor 4   timeTracker
# 0    0.000000         0.0  1.572917e+09
# 1   -0.117893         0.0  1.572917e+09
# 2   -0.218518         0.0  1.572917e+09
# 3   -0.209529         0.0  1.572917e+09
# 4   -0.185043         0.0  1.572917e+09

# %%
fig = plt.figure(figsize = (15, 8))
plt.subplot(4,1,1)
plt.plot(df['Sensor 1'][2000:], 'b')
plt.show()

fig = plt.figure(figsize = (15, 8))
plt.subplot(4,1,2)
plt.plot(df['Sensor 2'][2000:], 'b')
plt.show()

fig = plt.figure(figsize = (15, 8))
plt.subplot(4,1,3)
plt.plot(df['Sensor 3'][2000:], 'b')
plt.show()

fig = plt.figure(figsize = (15, 8))
plt.subplot(4,1,4)
plt.plot(df['Sensor 4'][2000:], 'b')
plt.show()
