# %% [markdown]
# #### Examine raw data pulled from Read_Write_Sensor python script

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_excel('Data_2.xlsx')

df.head()
# Out:
#    Unnamed: 0  Sensor 1  Sensor 2  Sensor 3  Sensor 4  d_Sensor 1  d_Sensor 2  \
# 0           0  0.395000  0.465000  0.435000  0.415000    0.000000    0.000000
# 1           1  0.395000  0.475000  0.450000  0.420000    0.000000    0.487585
# 2           2  0.381667  0.471623  0.444901  0.421678   -0.390976    0.084318
# 3           3  0.387673  0.459764  0.437231  0.419994    0.026764   -0.505209
# 4           4  0.387116  0.454557  0.422136  0.418983   -0.013807   -0.525479
#
#    d_Sensor 3  d_Sensor 4   timeTracker
# 0    0.000000    0.000000  1.572985e+09
# 1    0.731378    0.243793  1.572985e+09
# 2    0.056582    0.201678  1.572985e+09
# 3   -0.387384    0.084185  1.572985e+09
# 4   -1.003597    0.024333  1.572985e+09

# %%
fig = plt.figure(figsize = (15, 8))
plt.subplot(4,1,1)
plt.plot(df['Sensor 1'][2000:], 'b')
plt.show()

fig = plt.figure(figsize = (15, 8))
plt.subplot(4,1,2)
plt.plot(df['Sensor 2'][2000:], 'b')
plt.show()

fig = plt.figure(figsize = (15, 8))
plt.subplot(4,1,3)
plt.plot(df['Sensor 3'][2000:], 'b')
plt.show()

fig = plt.figure(figsize = (15, 8))
plt.subplot(4,1,4)
plt.plot(df['Sensor 4'][2000:], 'b')
plt.show()
