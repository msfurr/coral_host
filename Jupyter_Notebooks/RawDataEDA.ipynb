# %% [markdown]
# #### Examine raw data pulled from Read_Write_Sensor python script

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('Results.csv')

df.head()
# Out:
#    Sensor 1  Sensor 2  Sensor 3  Sensor 4  d_Sensor 1  d_Sensor 2  d_Sensor 3  \
# 0  0.546083  0.579848  0.447090  0.460894    0.000000    0.000000    0.000000
# 1  0.541475  0.576046  0.452381  0.460894   -0.251256   -0.207310    0.288479
# 2  0.530656  0.562033  0.429292  0.427374   -0.639118   -0.741329   -0.937715
# 3  0.513292  0.546967  0.420021  0.415379   -1.200958   -1.174711   -0.965601
# 4  0.502488  0.536055  0.414474  0.408219   -1.169066   -1.163255   -0.811522
#
#    d_Sensor 4   timeTracker
# 0    0.000000  1.573605e+09
# 1    0.000000  1.573605e+09
# 2   -1.168963  1.573605e+09
# 3   -1.231394  1.573605e+09
# 4   -1.036095  1.573605e+09

# %%
fig = plt.figure(figsize = (15, 8))
plt.subplot(4,1,1)
plt.plot(df['Sensor 1'], 'b')
plt.show()

fig = plt.figure(figsize = (15, 8))
plt.subplot(4,1,2)
plt.plot(df['Sensor 2'], 'b')
plt.show()

fig = plt.figure(figsize = (15, 8))
plt.subplot(4,1,3)
plt.plot(df['Sensor 3'], 'b')
plt.show()

fig = plt.figure(figsize = (15, 8))
plt.subplot(4,1,4)
plt.plot(df['Sensor 4'], 'b')
plt.show()

# %%
fig = plt.figure(figsize = (15, 8))
plt.plot(df['Sensor 1'][500:1000], 'b')
plt.show()

# %%
test = df['Sensor 1'][500:1000]

# %%
1-max(test[-200:-1])
# Out:
# 0.3663062958244603
