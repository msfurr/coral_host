# %% [markdown]
# #### Examine raw data pulled from Read_Write_Sensor python script

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_excel('Training_2.xlsx')

df.head()
# Out:
#    Unnamed: 0  Sensor 1  Sensor 2  Sensor 3  Sensor 4  d_Sensor 1  d_Sensor 2  \
# 0           0  0.425000  0.435000  0.405000     0.425    0.000000    0.000000
# 1           1  0.425000  0.430000  0.405000     0.425    0.000000   -0.244389
# 2           2  0.418333  0.414900  0.395000     0.425   -0.205936   -0.750222
# 3           3  0.414950  0.414926  0.397556     0.425   -0.253372   -0.370822
# 4           4  0.408825  0.417003  0.399083     0.425   -0.370188   -0.084683
#
#    d_Sensor 3  d_Sensor 4   timeTracker
# 0    0.000000         0.0  1.572986e+09
# 1    0.000000         0.0  1.572986e+09
# 2   -0.308904         0.0  1.572986e+09
# 3   -0.079622         0.0  1.572986e+09
# 4    0.017312         0.0  1.572986e+09

# %%
fig = plt.figure(figsize = (15, 8))
plt.subplot(4,1,1)
plt.plot(df['Sensor 1'], 'b')
plt.show()

fig = plt.figure(figsize = (15, 8))
plt.subplot(4,1,2)
plt.plot(df['Sensor 2'], 'b')
plt.show()

fig = plt.figure(figsize = (15, 8))
plt.subplot(4,1,3)
plt.plot(df['Sensor 3'], 'b')
plt.show()

fig = plt.figure(figsize = (15, 8))
plt.subplot(4,1,4)
plt.plot(df['Sensor 4'], 'b')
plt.show()
