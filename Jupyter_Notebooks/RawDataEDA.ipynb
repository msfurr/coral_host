# %% [markdown]
# #### Examine raw data pulled from Read_Write_Sensor python script

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('Results.csv')

df.head()

fig = plt.figure(figsize = (15, 8))
plt.subplot(4,1,1)
plt.ylim(0, 1)
plt.plot(df['Sensor 1'], 'b')
plt.show()

fig = plt.figure(figsize = (15, 8))
plt.subplot(4,1,2)
plt.ylim(0, 1)
plt.plot(df['Sensor 2'], 'b')
plt.show()

fig = plt.figure(figsize = (15, 8))
plt.subplot(4,1,3)
plt.ylim(0, 1)
plt.plot(df['Sensor 3'], 'b')
plt.show()

fig = plt.figure(figsize = (15, 8))
plt.subplot(4,1,4)
plt.ylim(0, 1)
plt.plot(df['Sensor 4'], 'b')
plt.show()

# %%
fig = plt.figure(figsize = (15, 8))
plt.subplot(4,1,1)
plt.plot(df['d_Sensor 1'], 'b')
plt.show()

fig = plt.figure(figsize = (15, 8))
plt.subplot(4,1,2)
plt.plot(df['d_Sensor 2'], 'b')
plt.show()

fig = plt.figure(figsize = (15, 8))
plt.subplot(4,1,3)
plt.plot(df['d_Sensor 3'], 'b')
plt.show()

fig = plt.figure(figsize = (15, 8))
plt.subplot(4,1,4)
plt.plot(df['d_Sensor 4'], 'b')
plt.show()

# %%
fig = plt.figure(figsize = (15, 8))
plt.ylim(0, 1)
plt.plot(df['Sensor 1'][1000:2000], 'b')
plt.show()
