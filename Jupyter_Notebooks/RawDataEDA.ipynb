# %% [markdown]
# #### Examine raw data pulled from Read_Write_Sensor python script

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_excel('TrainingData_11_6.xlsx')

df.head()
# Out:
#    Unnamed: 0  Sensor 1  Sensor 2  Sensor 3  Sensor 4  d_Sensor 1  d_Sensor 2  \
# 0           0  0.448000  0.472000  0.448000  0.488889    0.000000    0.000000
# 1           1  0.448000  0.476000  0.452000  0.488889    0.000000    0.217988
# 2           2  0.442667  0.471979  0.453340  0.491852   -0.187120   -0.056650
# 3           3  0.441992  0.467932  0.447968  0.493343   -0.141453   -0.180708
# 4           4  0.443208  0.468765  0.451247  0.494239   -0.063514   -0.083391
#
#    d_Sensor 3  d_Sensor 4   timeTracker
# 0    0.000000    0.000000  1.573070e+09
# 1    0.217988    0.000000  1.573070e+09
# 2    0.185052    0.103955  1.573070e+09
# 3   -0.020557    0.111506  1.573070e+09
# 4    0.110181    0.107435  1.573070e+09

# %%
fig = plt.figure(figsize = (15, 8))
plt.subplot(4,1,1)
plt.plot(df['Sensor 1'], 'b')
plt.show()

fig = plt.figure(figsize = (15, 8))
plt.subplot(4,1,2)
plt.plot(df['Sensor 2'], 'b')
plt.show()

fig = plt.figure(figsize = (15, 8))
plt.subplot(4,1,3)
plt.plot(df['Sensor 3'], 'b')
plt.show()

fig = plt.figure(figsize = (15, 8))
plt.subplot(4,1,4)
plt.plot(df['Sensor 4'], 'b')
plt.show()
