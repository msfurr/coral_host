# %% [markdown]
# #### Examine raw data pulled from Read_Write_Sensor python script

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('sensor_walking_5.csv')

df.head()
# Out:
#    Sensor 1  Sensor 2  Sensor 3  Sensor 4  d_Sensor 1  d_Sensor 2  d_Sensor 3  \
# 0  0.665746  0.726244  0.673184  0.676796    0.000000    0.000000    0.000000
# 1  0.665746  0.730769  0.673184  0.676796    0.000000    0.220961    0.000000
# 2  0.658379  0.717113  0.654562  0.662063   -0.224616   -0.410323   -0.567814
# 3  0.646212  0.707769  0.650684  0.657308   -0.557514   -0.651668   -0.463611
# 4  0.638701  0.704022  0.650716  0.652163   -0.615993   -0.514843   -0.286003
#
#    d_Sensor 4   timeTracker
# 0    0.000000  1.573614e+09
# 1    0.000000  1.573614e+09
# 2   -0.449232  1.573614e+09
# 3   -0.444241  1.573614e+09
# 4   -0.454083  1.573614e+09

# %%
fig = plt.figure(figsize = (15, 8))
plt.subplot(4,1,1)
plt.plot(df['Sensor 1'], 'b')
plt.show()

fig = plt.figure(figsize = (15, 8))
plt.subplot(4,1,2)
plt.plot(df['Sensor 2'], 'b')
plt.show()

fig = plt.figure(figsize = (15, 8))
plt.subplot(4,1,3)
plt.plot(df['Sensor 3'], 'b')
plt.show()

fig = plt.figure(figsize = (15, 8))
plt.subplot(4,1,4)
plt.plot(df['Sensor 4'], 'b')
plt.show()

# %%
fig = plt.figure(figsize = (15, 8))
plt.plot(df['Sensor 1'][500:1000], 'b')
plt.show()

# %%
test = df['Sensor 1'][500:1000]

# %%
1-max(test[-200:-1])
# Out:
# 0.3663062958244603
